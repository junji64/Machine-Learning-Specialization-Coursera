# %% [markdown]
# # Optional Lab:  Python 및 Jupyter Notebook에 대한 간략한 소개
# 첫 번째 실습에 오신 것을 환영합니다! 실습을 통해 다음을 수행할 수 있습니다.
#
# * 정보 제공 - 이 노트처럼
# * 실습 예제를 통해 강의 자료 강화
# * 체점되는 괴제에서 사용되는 루틴의 실제 예를 제공합니다.

# %% [markdown]
# ## Goals
# 이 실습에서는 다음을 수행합니다.
# - Jupyter Notebook에 대한 간략한 소개를 받아보세요.
# - Jupyter Notebook 둘러보기
# - markdown 셀과 code 셀의 차이점 알아보기
# - 기본적인 파이썬을 연습해 보세요.

# %% [markdown]
# Jupyter Notebook에 익숙해지는 가장 쉬운 방법은 Help 메뉴에서 위에 있는 ture 를 이용하는 것입니다.

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Jupyter Notebook에는 이 과정에서 사용되는 두 가지 유형의 셀이 있습니다. 'Markdown Cells' 라는 문서가 포함된 이와 같은 셀입니다. 이름은 셀에 사용되는 간단한 형식 지정 언어에서 파생되었습니다. Markdown 셀을 생성할 필요가 없습니다. 아래 그래픽에 표시된 `cell pulldown`을 이해하는 것이 유용합니다. 가끔 셀이 잘못된 모드로 전환되어 올바른 상태로 복원해야 할 수도 있습니다.

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 다른 유형의 셀은 코드를 작성할 `code cell`입니다.

# %%
#This is  a 'Code' Cell
print("This is  code cell")
# Out:
# This is  code cell

# %% [markdown]
# ## Python
# code cells에 코드를 작성할 수 있습니다.
# 코드를 실행하려면 셀을 선택하고 다음 중 하나를 수행합니다.
# - Shift-키를 누른 상태에서 'Enter' 또는 'Return'을 누르세요.
# - 위의  'run' 화살표를 클릭하세요.
#
# <figure>
#     <img src="./images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### Print statement
# Print 문은 일반적으로 Python f-string 스타일을 사용합니다.
# 다음 셀에서 자신만의 인쇄물을 만들어 보세요.
# 셀을 실행하는 두 가지 방법을 모두 시도해 보십시오.

# %%
# print statements
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # Congratulations!
# You now know how to find your way around a Jupyter Notebook.
